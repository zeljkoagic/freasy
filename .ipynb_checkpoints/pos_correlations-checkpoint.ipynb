# %%
#from matplotlib import rc
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=(5, 5))
from scipy.stats import pearsonr

#rc('text', usetex=True)

pos_accs = [51.48,69.99,78.24,84.89,67.54,62.44,79.75,86.60,76.11,28.04,68.23,78.80,62.64,51.62,75.95,68.38,77.78,87.69,71.49,86.31,79.07,85.98,75.77,76.53,88.19,43.49,95.82,97.64,98.32,95.56,92.65,97.78,94.48,95.08,95.26,96.55,95.34,96.35,94.95,96.32,95.15,94.57,93.63,97.62,89.34,97.28,96.26,96.90,95.70,96.22,96.25,87.53]
wals_abs = [0.24,10.00,1.79,0.19,0.11,0.82,1.27,0.00,0.00,8.88,0.00,0.51,5.12,21.52,0.00,3.92,6.28,0.15,0.91,3.09,1.41,0.00,0.42,3.97,3.50,6.23,3.72,2.16,0.32,0.27,0.00,3.56,2.00,0.00,0.00,0.37,0.00,0.04,0.00,1.02,0.00,5.14,6.24,0.16,3.23,1.36,2.58,1.19,13.31,0.00,1.25,0.00]
kl_abs = [2.51,0.45,0.17,0.40,0.63,0.00,1.98,1.01,0.60,2.67,0.22,0.59,0.00,21.73,0.27,8.08,0.01,0.10,0.34,1.69,1.70,0.43,5.14,0.64,0.52,3.97,0.07,16.68,4.07,0.61,0.03,15.12,0.02,0.00,0.00,12.53,0.00,0.04,11.13,34.93,0.54,5.50,8.12,2.17,2.50,4.03,2.23,0.00,3.09,5.67,5.02,0.00]


plt.scatter(pos_accs, wals_abs, color="blue", label="wals")
plt.scatter(pos_accs, kl_abs, color="red", label="kl")

plt.rcParams.update({'font.size': 14})
plt.legend()
#plt.legend(bbox_to_anchor=(0.5, 1.28), loc=2, borderaxespad=0., frameon=False, ncol=4)
#plt.title("A: source selection")
#plt.ylabel("UAS")
#plt.xlim(90,97)
#plt.ylim(0,10)

fig.tight_layout()

# %%
print(pearsonr(pos_accs, wals_abs))
print(pearsonr(pos_accs, kl_abs))
# Out:
# (-0.3971235533796123, 0.0035568946812768332)
# (0.082486915013570972, 0.56100174321975338)
