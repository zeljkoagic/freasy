# %%
# %env:LC_ALL="en_US.UTF-8"
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt


means_women = (49.48, 51.96, 53.53, 51.40, 50.20, 52.32) # 51.40
std_women = (5.37, 4.35, 5.48, 5.71, 5.20, 5.30)

fig = plt.figure(figsize=(8.5, 5))

#fig, ax = plt.subplots()

plt.ylim([35,60])

index = np.arange(6)
bar_width = 0.5
error_config = {'ecolor': '0.5', "linewidth": "1"}
opacity = 1
colors = ['deepskyblue','deepskyblue','lightsalmon','lightsalmon', 'lime', 'lime']
colors_outer = ['blue','blue','red','red', 'darkgreen', 'darkgreen']
rects2 = plt.bar(index + bar_width, means_women, bar_width,
                 alpha=opacity,
                 color=colors,
                 yerr=std_women,
                 error_kw=error_config,
                 align="center",
                 linewidth=1,
                 edgecolor=colors_outer)

plt.ylabel('UAS')
plt.xticks(index + bar_width, ('MULTI', 'SINGLE', 'PROJ1', 'PROJ2', 'selection', 'reparsing'))

plt.axhline(53.53, linestyle="--", color="0.5")
plt.axhline(51.40, linestyle="--", color="0.5")

plt.tight_layout()
plt.rcParams.update({'font.size': 16})
# Out:
# env: :LC_ALL="en_US.UTF-8"

# %%
means_rank = (71.34, 16.35, 5.06, 2.77, 1.82, 0.38, 2.27, 28.66)
ci_rank = (11.09, 9.30, 5.17, 2.94, 2.01, 0.43, np.nan, np.nan)

fig = plt.figure(figsize=(8.5, 5))

#fig, ax = plt.subplots()

plt.ylim([0,85])
plt.xlim([0,8])

index = np.arange(8)
bar_width = 0.5
error_config = {'ecolor': '0.5', "linewidth": "1"}
opacity = 1
colors = ['deepskyblue', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon', 'lightsalmon']
colors_outer = ['blue', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red']
rects2 = plt.bar(index + bar_width, means_rank, bar_width,
                 alpha=opacity,
                 color=colors,
                 yerr=ci_rank,
                 error_kw=error_config,
                 align="center",
                 linewidth=1,
                 edgecolor=colors_outer)

plt.ylabel('best for % sentences')
plt.xlabel('test set rank of best source')
plt.xticks(index + bar_width, (1,2,3,4,5,6,"7-25", "2-25"))

plt.axhline(28.66, color="0.5", linestyle="--")
plt.axvline(6, color="black", linestyle="-")

plt.tight_layout()
plt.rcParams.update({'font.size': 16})
